# %% [markdown]
# # Overview
#
# We're now switching focus away from the Network Science (for a little bit), beginning to think about _Natural Language Processing_ instead. In other words, today will be all about teaching your computer to "understand" text. This ties in nicely with our work on wikipedia, since wikipedia is a network of connected pieces of text. We've looked at the network so far - now, let's see if we can include the text. Today is about
#
# * Installing the _natural language toolkit_ (NLTK) package and learning the basics of how it works (Chapter 1)
# * Figuring out how to make NLTK to work with other types of text (Chapter 2).
#
# ## The informal lecture
#
# Again. We're in work-mode. I've dispensed most of the practical info, to you so just a quick pep-talk today.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("[link]",width=800, height=450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="https://www.youtube.com/embed/[link]"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Part 1: A little lecture
#
# > **_Video Lecture_**. Today is all about ***working*** with NLTK, so not much lecturing - you can get my perspective and a little pep-talk

# %%
YouTubeVideo("Ph0EHmFT3n4",width=800, height=450)

# %% [markdown]
# # Part 2: Installing and the basics
#
# > _Reading_
# > The reading for today is Natural Language Processing with Python (NLPP) Chapter 1, Sections 1.1, 1.2, 1.3\. [It's free online](http://www.nltk.org/book/).

# %% [markdown]
# > *Exercises*: NLPP Chapter 1\.
# >
# > * First, install `nltk` if it isn't installed already (there are some tips below that I recommend checking out before doing installing)
# > * Second, work through chapter 1. The book is set up as a kind of tutorial with lots of examples for you to work through. I recommend you read the text with an open Jupyter Notebook and type out the examples that you see. ***It becomes much more fun if you to add a few variations and see what happens***. Some of those examples might very well be due as assignments (see below the install tips), so those ones should definitely be in a `notebook`.

# %% [markdown]
# ### NLTK Install tips
#
# Check to see if `nltk` is installed on your system by typing `import nltk` in a `notebook`. If it's not already installed, install it as part of _Anaconda_ by typing
#
#      conda install nltk
#
# at the command prompt. If you don't have them, you can download the various corpora using a command-line version of the downloader that runs in Python notebooks: In the iPython notebook, run the code
#
#      import nltk
#      nltk.download()
#
# Now you can hit `d` to download, then type "book" to fetch the collection needed today's `nltk` session. Now that everything is up and running, let's get to the actual exercises.

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# > *Exercises: NLPP Chapter 1 (the stuff that might be due in an upcoming assignment).
# >
# > The following exercises from Chapter 1 are what might be due in an assignment later on.
# >
# > * Try out the `concordance` method, using another text and a word of your own choosing.
# > * Also try out the `similar` and `common_context` methods for a few of your own examples.
# > * Create your own version of a dispersion plot ("your own version" means another text and different word).
# > * Explain in your own words what aspect of language _lexical diversity_ describes.
# > * Create frequency distributions for `text2`, including the cumulative frequency plot for the 75 most common words.
# > * What is a bigram? How does it relate to `collocations`. Explain in your own words.
# > * Work through ex 2-12 in NLPP's section 1.8\.
# > * Work through exercise 15, 17, 19, 22, 23, 26, 27, 28 in section 1.8\.

# %% [markdown]
# ### Try out the concordance method, using another text and a word of your own choosing.

# %%
text2.concordance("affection")
# Out:
# Displaying 25 of 79 matches:
# , however , and , as a mark of his affection for the three girls , he left them
# t . It was very well known that no affection was ever supposed to exist between
# deration of politeness or maternal affection on the side of the former , the tw
# d the suspicion -- the hope of his affection for me may warrant , without impru
# hich forbade the indulgence of his affection . She knew that his mother neither
# rd she gave one with still greater affection . Though her late conversation wit
#  can never hope to feel or inspire affection again , and if her home be uncomfo
# m of the sense , elegance , mutual affection , and domestic comfort of the fami
# , and which recommended him to her affection beyond every thing else . His soci
# ween the parties might forward the affection of Mr . Willoughby , an equally st
#  the most pointed assurance of her affection . Elinor could not be surprised at
# ...

# %% [markdown]
# ### Also try out the similar and common_context methods for a few of your own examples.

# %%
text2.similar("affection")
# Out:
# attention time regard mother love heart opinion sister wishes wife
# arrival marianne kindness family it marriage sisters sake conduct mind

# %%
text2.common_contexts(["day", "week"])
# Out:
# a_or a_i the_i a_in

# %% [markdown]
# ### Create your own version of a dispersion plot ("your own version" means another text and different word).

# %%
text6.dispersion_plot(["a", "the", "this", "that"])

# %% [markdown]
# ### Explain in your own words what aspect of language lexical diversity describes.

# %% [markdown]
# The variety of the language in term of different words usage

# %% [markdown]
# ### Create frequency distributions for text2, including the cumulative frequency plot for the 75 most common words.

# %%
fdist2 = FreqDist(text2)
fdist2.most_common(75)
# Out:
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179),
#  ('you', 1037),
#  ('with', 971),
#  ('had', 969),
#  ('his', 941),
#  ('he', 895),
#  ("'", 883),
#  ('have', 807),
#  ('at', 806),
#  ('by', 737),
#  ('is', 728),
#  ('."', 721),
#  ('s', 700),
#  ('Elinor', 684),
#  ('on', 676),
#  ('all', 642),
#  ('him', 633),
#  ('so', 617),
#  ('but', 597),
#  ('which', 592),
#  ('could', 568),
#  ('Marianne', 566),
#  ('my', 551),
#  ('Mrs', 530),
#  ('from', 527),
#  ('would', 507),
#  ('very', 492),
#  ('no', 488),
#  ('their', 463),
#  ('them', 462),
#  ('--', 461),
#  ('been', 440),
#  ('were', 437),
#  ('me', 433),
#  ('they', 428),
#  ('more', 406),
#  ('said', 397),
#  (',"', 396),
#  ('any', 389),
# ...

# %% [markdown]
# ### What is a bigram? How does it relate to collocations. Explain in your own words.

# %% [markdown]
# A bigram is a list of word pairs which is used as an input to calculate collocations.

# %% [markdown]
# ## Work through ex 2-12 in NLPP's section 1.8.

# %% [markdown]
# ###  2 Given an alphabet of 26 letters, there are 26 to the power 10, or 26 ** 10, ten-letter strings we can form. That works out to 141167095653376. How many hundred-letter strings are possible?

# %%
26**100
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %% [markdown]
# ### 3 The Python multiplication operation can be applied to lists. What happens when you type ['Monty', 'Python'] * 20, or 3 * sent1?

# %% [markdown]
# When type ['Monty', 'Python'] * 20 a new list with 20 times Monty and Python will be created, when type 3 * sent1 a new string with 3 times the content of sent1 will be created

# %% [markdown]
# ### 4 Review 1 on computing with language. How many words are there in text2? How many distinct words are there?

# %%
# Words
print(len(text2), ' words in text2')
print(len(set(text2)), ' distinct words in text2')
# Out:
# 141576  words in text2
# 6833  distinct words in text2

# %% [markdown]
# ### 5 Compare the lexical diversity scores for humor and romance fiction in 1.1. Which genre is more lexically diverse?

# %% [markdown]
# According from the table, the humor is more lexically diverse than fiction: romance

# %% [markdown]
# ### 6 Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %% [markdown]
# The Elinor and Marianne appears much more frequent than dward Willoughby. From the plot, Elinor and Marianne could be a couple, since they are often showing up at same time.

# %% [markdown]
# ### 7  Find the collocations in text5.

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# ### 8  Consider the following Python expression: len(set(text4)). State the purpose of this expression. Describe the two steps involved in performing this computation.

# %% [markdown]
# Compute the number of distinct words in text4. the set() function creates a set data structrue in which no duplicate items are allowed, the len() function returns the number of item in any container like data structure.

# %% [markdown]
# ### 9  Review 2 on lists and strings.
#
#     Define a string and assign it to a variable, e.g., my_string = 'My String' (but put something more interesting in the string). Print the contents of this variable in two ways, first by simply typing the variable name and pressing enter, then by using the print statement.
#     Try adding the string to itself using my_string + my_string, or multiplying it by a number, e.g., my_string * 3. Notice that the strings are joined together without any spaces. How could you fix this?

# %%
stringA = 'This is a string'
stringA
# Out:
# 'This is a string'

# %%
print(stringA)
# Out:
# This is a string

# %%
' '.join([stringA] * 3)
# Out:
# 'This is a string This is a string This is a string'

# %% [markdown]
# ### 10 Define a variable my_sent to be a list of words, using the syntax my_sent = ["My", "sent"] (but with your own words, or a favorite saying).
#
#     Use ' '.join(my_sent) to convert this into a string.
#     Use split() to split the string back into the list form you had to start with.

# %%
my_sent = ["Hello", "World"]
my_sent = ' '.join(my_sent)
print(my_sent)
# Out:
# Hello World

# %%
my_sent.split()
# Out:
# ['Hello', 'World']

# %% [markdown]
# ### 11 Define several variables containing lists of words, e.g., phrase1, phrase2, and so on. Join them together in various combinations (using the plus operator) to form whole sentences. What is the relationship between len(phrase1 + phrase2) and len(phrase1) + len(phrase2)?

# %% [markdown]
# len(phrase1 + phrase2) create a new list which contains the words from both phrase1 and phrase2 then, calculate the length of it, the len(phrase1) + len(phrase1) calculate the length of phrase1 and phrase2 seperatly and sum them together and return

# %% [markdown]
# ### 12 Consider the following two expressions, which have the same value. Which one will typically be more relevant in NLP? Why?
#
#     a. "Monty Python"[6:12]
#     b. ["Monty", "Python"][1]

# %% [markdown]
# a will be more relevant in NLP, because a is extracting word from text, b is simply doing a list indexing

# %% [markdown]
# ## Work through exercise 15, 17, 19, 22, 23, 26, 27, 28 in section 1.8.

# %% [markdown]
# ### 15  Review the discussion of conditionals in 4. Find all words in the Chat Corpus (text5) starting with the letter b. Show them in alphabetical order.

# %%
sorted([word for word in set(text5) if word.startswith("b")])
# Out:
# ['b',
#  'b-day',
#  'b/c',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babes',
#  'babi',
#  'babies',
#  'babiess',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'backatchya',
#  'backfrontsidewaysandallaroundtheworld',
#  'backroom',
#  'backup',
#  'bacl',
#  'bad',
#  'bag',
#  'bagel',
#  'bagels',
#  'bahahahaa',
#  'bak',
#  'baked',
#  'balad',
#  'balance',
#  'balck',
#  'ball',
#  'ballin',
#  'balls',
#  'ban',
#  'band',
#  'bandito',
#  'bandsaw',
#  'banjoes',
#  'banned',
#  'baord',
#  'bar',
#  'barbie',
#  'bare',
#  'barely',
#  'bares',
#  'barfights',
#  'barks',
#  'barn',
#  'barrel',
#  'base',
#  'bases',
#  'basically',
#  'basket',
#  'battery',
#  'bay',
#  'bbbbbyyyyyyyeeeeeeeee',
#  'bbiam',
#  'bbl',
#  'bbs',
#  'bc',
#  'be',
#  'beach',
#  'beachhhh',
#  'beam',
#  'beams',
#  'beanbag',
#  'beans',
#  'bear',
#  'bears',
#  'beat',
#  'beaten',
#  'beatles',
#  'beats',
#  'beattles',
#  'beautiful',
# ...

# %% [markdown]
# ### 17 Use text9.index() to find the index of the word sunset. You'll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
indx = text9.index('sunset')
i, j = indx, indx
while i >= 0 and text9[i] != '.':
    i -= 1

while j < len(text9) and text9[j] != '.':
    j += 1

" ".join(text9[i+1:j+1])
# Out:
# 'CHAPTER I THE TWO POETS OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .'

# %% [markdown]
# ### 19 What is the difference between the following two lines? Which one will give a larger value? Will this be the case for other texts?
#
#     >>> sorted(set(w.lower() for w in text1))
#     >>> sorted(w.lower() for w in set(text1))

# %% [markdown]
# The first one convert every word in text1 to lower case then perform a set operation, the second one first perform a set operation then convert every word of the resulf to lower cases.
#
# The second one will gives a longer list of words, because for example, words like 'case' and 'CASE' will be combined to one single item in the first experssion, while in the second one, they will be retained.
#
# Yes

# %% [markdown]
# ### 22 Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %%
fourLetterWord = [word for word in set(text5) if len(word) == 4]
d = FreqDist(text5)
words = [(key, d[key]) for key in fourLetterWord]
sorted(words, key=lambda item: item[1], reverse=True)
# Out:
# [('JOIN', 1021),
#  ('PART', 1016),
#  ('that', 274),
#  ('what', 183),
#  ('here', 181),
#  ('....', 170),
#  ('have', 164),
#  ('like', 156),
#  ('with', 152),
#  ('chat', 142),
#  ('your', 137),
#  ('good', 130),
#  ('just', 125),
#  ('lmao', 107),
#  ('know', 103),
#  ('room', 98),
#  ('from', 92),
#  ('this', 86),
#  ('well', 81),
#  ('back', 78),
#  ('hiya', 78),
#  ('they', 77),
#  ('yeah', 75),
#  ('dont', 75),
#  ('want', 71),
#  ('love', 60),
#  ('some', 58),
#  ('guys', 58),
#  ('been', 57),
#  ('talk', 56),
#  ('nice', 52),
#  ('time', 50),
#  ('when', 48),
#  ('make', 44),
#  ('haha', 44),
#  ('need', 43),
#  ('girl', 43),
#  ('U122', 42),
#  ('MODE', 41),
#  ('then', 40),
#  ('will', 40),
#  ('much', 40),
#  ('over', 39),
#  ('were', 38),
#  ('work', 38),
#  ('take', 37),
#  ('U121', 36),
#  ('song', 36),
#  ('U115', 36),
#  ('U105', 35),
#  ('even', 35),
#  ('U156', 35),
#  ('seen', 35),
#  ('does', 35),
#  ('damn', 34),
#  ('more', 34),
#  ('only', 33),
# ...

# %% [markdown]
# ### 23 Review the discussion of looping with conditions in 4. Use a combination of for and if statements to loop over the words of the movie script for Monty Python and the Holy Grail (text6) and print all the uppercase words, one per line.

# %%
[word for word in set(text6) if word == word.upper() and word.isalpha()]
# Out:
# ['SHRUBBER',
#  'MAN',
#  'VILLAGERS',
#  'BROTHER',
#  'ARTHUR',
#  'GUESTS',
#  'LUCKY',
#  'HEADS',
#  'MAYNARD',
#  'DINGO',
#  'PRINCE',
#  'GIRLS',
#  'DEAD',
#  'C',
#  'SUN',
#  'PARTY',
#  'SOLDIER',
#  'CRASH',
#  'MASTER',
#  'WIFE',
#  'WITCH',
#  'W',
#  'PATSY',
#  'CONCORDE',
#  'BRIDGEKEEPER',
#  'A',
#  'GREEN',
#  'MINSTREL',
#  'KNIGHTS',
#  'SIR',
#  'AMAZING',
#  'BEDEVERE',
#  'GUARD',
#  'GOD',
#  'CAMERAMAN',
#  'BORS',
#  'ANIMATOR',
#  'SCENE',
#  'RIGHT',
#  'ALL',
#  'PERSON',
#  'CRONE',
#  'CHARACTERS',
#  'STUNNER',
#  'VOICE',
#  'N',
#  'HISTORIAN',
#  'DENNIS',
#  'CHARACTER',
#  'CART',
#  'OF',
#  'WINSTON',
#  'NARRATOR',
#  'Y',
#  'GALAHAD',
#  'GUEST',
#  'VILLAGER',
#  'ROBIN',
#  'PRISONER',
#  'S',
#  'KNIGHT',
#  'PIGLET',
#  'CARTOON',
#  'SENTRY',
#  'HEAD',
#  'LEFT',
#  'LOVELY',
#  'RANDOM',
#  'MONKS',
#  'OFFICER',
#  'B',
#  'TIM',
#  'FATHER',
#  'HERBERT',
#  'DIRECTOR',
#  'PRINCESS',
#  'FRENCH',
#  'KING',
#  'THE',
#  'NI',
# ...

# %% [markdown]
# ### 26 What does the following Python code do? sum(len(w) for w in text1) Can you use it to work out the average word length of a text?

# %% [markdown]
# Get the length of every word and sum them, together

# %%
sum(len(w) for w in text1) / len(text1)
# Out:
# 3.830411128023649

# %% [markdown]
# ### 27 Define a function called vocab_size(text) that has a single parameter for the text, and which returns the vocabulary size of the text.

# %%
def vocab_size(text):
    return len(set(word.lower() for word in text if word.isalpha()))

# %% [markdown]
# ### 28 Define a function percent(word, text) that calculates how often a given word occurs in a text, and expresses the result as a percentage.

# %%
def percent(word, text):
    return text.count(word) * 1.0 / len(text)

# %% [markdown]
# # Part 3: Working with NLTK and other types of text
#
# So far, we've worked with text from Wikipedia. But that's not the only source of text in the universe. In fact, it's far from it. Chapter 2 in NLPP is all about getting access to nicely curated texts that you can find built into NLTK.
# >
# > Reading: NLPP Chapter 2.1 - 2.4\.
# >

# %% [markdown]
# > *Exercises*: NLPP Chapter 2\.
# >
# > * Solve exercise 4, 8, 11, 15, 16, 17, 18 in NLPP, section 2.8\. As always, I recommend you write up your solutions nicely in a `notebook`.
# > * Work through exercise 2.8.23 on Zipf's law. [Zipf's law](https://en.wikipedia.org/wiki/Zipf%27s_law) connects to a property of the Barabasi-Albert networks. Which one? Take a look at [this article](http://www.hpl.hp.com/research/idl/papers/ranking/adamicglottometrics.pdf) and write a paragraph or two describing other important instances of power-laws found on the internet.
# >

# %% [markdown]
# ## Solve exercise 4, 8, 11, 15, 16, 17, 18 in NLPP, section 2.8.

# %% [markdown]
# ### 4 Read in the texts of the State of the Union addresses, using the state_union corpus reader. Count occurrences of men, women, and people in each document. What has happened to the usage of these words over time?

# %%
from nltk.corpus import state_union
import matplotlib.pyplot as plt

# %%
years = []
menCount = []
womenCount = []
peopleCount = []
for name in state_union.fileids():
    years.append(name[:4])
    words = state_union.words(name)
    menCount.append(words.count("men"))
    womenCount.append(words.count("women"))
    peopleCount.append(words.count("people"))

# %%
plt.plot(years, menCount, label = "men occurrences count")
plt.plot(years, womenCount, label = "wome n occurrences count")
plt.plot(years, peopleCount, label = "people occurrences count")
plt.xlabel('years')
plt.ylabel('Counts')
plt.title('Word counts over years')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# From the plot, the usage of word people has an obvious increasment.The word men and women remains roughly the same

# %% [markdown]
# ### 8 Define a conditional frequency distribution over the Names corpus that allows you to see which initial letters are more frequent for males vs. females (cf. 4.4).

# %%
names = nltk.corpus.names
male_names = names.words('male.txt')
emale_names = names.words('female.txt')
cfd = nltk.ConditionalFreqDist(
           (fileid, name[0])
           for fileid in names.fileids()
            for name in names.words(fileid))
cfd.plot(title='Initial letter count in male.txt and female.txt')
# Out:
# <AxesSubplot:title={'center':'Initial letter count in male.txt and female.txt'}, xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### 11 Investigate the table of modal distributions and look for other patterns. Try to explain them in terms of your own impressionistic understanding of the different genres. Can you find other closed classes of words that exhibit significant differences across different genres?

# %% [markdown]
# The most frequent modal in religion is can, while in science_fiction it's could. In religion context, usually the content contains something like Gods can do something for you, so the most frequent modal is can, however in science_fiction, people often see a sentence said in future perspective.

# %% [markdown]
# ### 15 Write a program to find all words that occur at least three times in the Brown Corpus.

# %%
from collections import Counter
from nltk.corpus import brown

# %%
counter = Counter(brown.words())
[key for key in counter.keys() if key.isalpha() and counter[key] >= 3]
# Out:
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigation',
#  'of',
#  'recent',
#  'primary',
#  'election',
#  'produced',
#  'no',
#  'evidence',
#  'that',
#  'any',
#  'irregularities',
#  'took',
#  'place',
#  'jury',
#  'further',
#  'in',
#  'the',
#  'City',
#  'Executive',
#  'Committee',
#  'which',
#  'had',
#  'charge',
#  'deserves',
#  'praise',
#  'and',
#  'thanks',
#  'Atlanta',
#  'for',
#  'manner',
#  'was',
#  'conducted',
#  'term',
#  'been',
#  'charged',
#  'by',
#  'Superior',
#  'Court',
#  'Judge',
#  'to',
#  'investigate',
#  'reports',
#  'possible',
#  'won',
#  'Ivan',
#  'Allen',
#  'Only',
#  'a',
#  'relative',
#  'handful',
#  'such',
#  'received',
#  'considering',
#  'widespread',
#  'interest',
#  'number',
#  'voters',
#  'size',
#  'this',
#  'city',
#  'it',
#  'did',
#  'find',
#  'many',
#  'registration',
#  'laws',
#  'are',
#  'outmoded',
#  'or',
#  'inadequate',
#  'often',
# ...

# %% [markdown]
# ### 16 Write a program to generate a table of lexical diversity scores (i.e. token/type ratios), as we saw in 1.1. Include the full set of Brown Corpus genres (nltk.corpus.brown.categories()). Which genre has the lowest diversity (greatest number of tokens per type)? Is this what you would have expected?

# %%
brown.words(categories='news')
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
print("Genre, tokens, types, lexical diversity scores ")
for cat in brown.categories():
    words = brown.words(categories=cat)
    print(cat, len(words), len(set(words)), len(words) * 1.0 /len(set(words)))
# Out:
# Genre, tokens, types, lexical diversity scores
# adventure 69342 8874 7.814063556457065
# belles_lettres 173096 18421 9.396666847619565
# editorial 61604 9890 6.22891809908999
# fiction 68488 9302 7.362717695119329
# government 70117 8181 8.570712626818237
# hobbies 82345 11935 6.899455383326351
# humor 21695 5017 4.324297388877816
# learned 181888 16859 10.788777507562726
# lore 110299 14503 7.60525408536165
# mystery 57169 6982 8.188054998567745
# news 100554 14394 6.98582742809504
# religion 39399 6373 6.182174799937235
# reviews 40704 8626 4.718757245536749
# romance 70022 8452 8.284666351159489
# science_fiction 14470 3233 4.475719146303742

# %% [markdown]
# humor has the lowest diversity which is 4.324297388877816

# %% [markdown]
# ### 17 Write a function that finds the 50 most frequently occurring words of a text that are not stopwords

# %%
from nltk.corpus import stopwords

# %%
def top50NoneStop(text):
    stop = set(stopwords.words('english'))
    counter = Counter(text)
    rv = sorted([(key, counter[key]) for key in counter.keys() if key not in stop and key.isalpha()], key=lambda item: item[1], reverse=True)
    rv = rv[:50]
    return [item[0] for item in rv]

# %%
top50NoneStop(text1)
# Out:
# ['I',
#  'whale',
#  'one',
#  'But',
#  'like',
#  'The',
#  'upon',
#  'man',
#  'ship',
#  'Ahab',
#  'ye',
#  'old',
#  'sea',
#  'would',
#  'And',
#  'head',
#  'though',
#  'boat',
#  'time',
#  'long',
#  'It',
#  'said',
#  'yet',
#  'still',
#  'great',
#  'two',
#  'seemed',
#  'must',
#  'Whale',
#  'last',
#  'way',
#  'Stubb',
#  'see',
#  'Queequeg',
#  'little',
#  'round',
#  'whales',
#  'say',
#  'In',
#  'three',
#  'men',
#  'thou',
#  'He',
#  'may',
#  'us',
#  'every',
#  'much',
#  'could',
#  'Captain',
#  'first']

# %% [markdown]
# ### 18 Write a program to print the 50 most frequent bigrams (pairs of adjacent words) of a text, omitting bigrams that contain stopwords.

# %%
def top50Bigrams(text):
    stop = set(stopwords.words('english'))
    rv = set()
    for w1, w2 in bigrams(text):
        if w1 not in stop and w2 not in stop and w1.isalpha() and w2.isalpha():
            rv.add((w1, w2))
    
    counter = Counter(rv)
    top50 = sorted([(key, counter[key]) for key in counter], key=lambda item: item[1], reverse=True)[:50]
    top50 = [item[0] for item in top50]
    print(top50)

# %%
top50Bigrams(text1)
# Out:
# [('I', 'begin'), ('whaler', 'best'), ('escaping', 'except'), ('hole', 'prospect'), ('irresistible', 'arm'), ('Perchance', 'ye'), ('layer', 'upon'), ('like', 'god'), ('royal', 'stuff'), ('three', 'blue'), ('certain', 'wild'), ('significant', 'one'), ('easy', 'reach'), ('directly', 'behind'), ('standing', 'close'), ('milky', 'sea'), ('English', 'loam'), ('remains', 'undecipherable'), ('unusual', 'tokens'), ('CRUISE', 'IN'), ('found', 'sticking'), ('level', 'field'), ('soon', 'learn'), ('painstaking', 'burrower'), ('antagonistic', 'influences'), ('little', 'item'), ('small', 'number'), ('THE', 'SPERMACETI'), ('In', 'length'), ('His', 'lantern'), ('ever', 'actually'), ('sized', 'modern'), ('VOYAGES', 'TO'), ('harpoon', 'may'), ('yards', 'began'), ('nearly', 'morning'), ('live', 'enveloped'), ('lay', 'quiescent'), ('venture', 'upon'), ('spine', 'tapers'), ('little', 'resembled'), ('round', 'body'), ('wild', 'simultaneousness'), ('burning', 'finger'), ('luxurious', 'discomforts'), ('pointe
# ...

# %% [markdown]
# ## Work through exercise 2.8.23 on Zipf's law. Zipf's law connects to a property of the Barabasi-Albert networks. Which one? Take a look at this article and write a paragraph or two describing other important instances of power-laws found on the internet.

# %% [markdown]
# ### Write a function to process a large text and plot word frequency against word rank using pylab.plot. Do you confirm Zipf's law? (Hint: it helps to use a logarithmic scale). What is going on at the extreme ends of the plotted line?

# %%
def plotFrequencyRank(words):
    frequency = Counter(words)
    counts = sorted([(key, counter[key]) for key in frequency.keys()], key=lambda item: item[1], reverse=True)
    counts = [a for a, _ in counts]
    ranks = {}
    for indx, word in enumerate(counts, 1):
        ranks[word] = indx
    x, y = [], []
    for word in words:
        x.append(ranks[word])
        y.append(frequency[word])
    
    plt.loglog(x, y, 'o')
    plt.xlabel('Ranks')
    plt.ylabel('Frequency')
    plt.title('Word frequency against ranks')
    plt.show()

# %%
plotFrequencyRank(text4)

# %% [markdown]
# Yes, at the left top of the plot we can observe that the scatter plot follows a line goes to the down right, the frequency * rank are roughly remain the same.
#
# At the end of the plot, the rank keeps growing but the frequency remains the same

# %% [markdown]
# ### Generate random text, e.g., using random.choice("abcdefg "), taking care to include the space character. You will need to import random first. Use the string concatenation operator to accumulate characters into a (very) long string. Then tokenize this string, and generate the Zipf plot as before, and compare the two plots. What do you make of Zipf's Law in the light of this?

# %%
import random

# %%
def getLongRandomStr(length=10000):
    string = ''
    for i in range(length):
        string += random.choice("abcdefg ")
    return string

# %%
text = getLongRandomStr()
plotFrequencyRank(text.split())

# %% [markdown]
# The Zipf's Law doesn't fit for random generated text

# %% [markdown]
# The Barabasi-Albert networks has a power-law degree distribution
